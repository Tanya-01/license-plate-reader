# %% [markdown]
# # Clone repo

# %%
# !git clone https://github.com/KapilM26/PyTorch-YOLOv3.git
# Out:
# Cloning into 'PyTorch-YOLOv3'...
# remote: Enumerating objects: 724, done.
# remote: Total 724 (delta 0), reused 0 (delta 0), pack-reused 724
# Receiving objects: 100% (724/724), 16.18 MiB | 39.72 MiB/s, done.
# Resolving deltas: 100% (410/410), done.

# %% [markdown]
# # Move to google drive for easy access
# Dont forget to mount

# %%
# !mv PyTorch-YOLOv3 drive/My\ Drive/
# Out:
# drive  PyTorch-YOLOv3  sample_data

# %% [markdown]
# # Download backbone weights

# %%
# %cd drive/My\ Drive/PyTorch-YOLOv3/weights
# !bash download_weights.sh
# Out:
# /content/drive/My Drive/PyTorch-YOLOv3/weights
# --2020-10-27 13:07:57--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   166KB/s    in 21m 25s
#
# 2020-10-27 13:29:24 (188 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# --2020-10-27 13:29:25--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M   206KB/s    in 2m 53s
#
# ...

# %% [markdown]
# # Just moving data around, ignore

# %%
cp -r license_plate_data/images/* PyTorch-YOLOv3/data/custom/images
cp -r license_plate_data/yolo_anno/* PyTorch-YOLOv3/data/custom/labels

# %%
# %cd /content/drive/My\ Drive/PyTorch-YOLOv3
# Out:
# /content/drive/My Drive/PyTorch-YOLOv3

# %% [markdown]
# ## Tensorflow is needed since they have used tensorboard, nothing else
# ## They've used tensorboard which comes with 1.x, colab defaults to 2.x, so changed that

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # Create custom model with 1 class, as mentioned in repo readme

# %%
# %cd config
# !bash create_custom_model.sh 1
# %cd ..
# Out:
# /content/drive/My Drive/PyTorch-YOLOv3/config
# /content/drive/My Drive/PyTorch-YOLOv3

# %% [markdown]
# # Install dependency

# %%
# !pip install terminaltables
# Out:
# ...
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-cp36-none-any.whl size=15356 sha256=d69eb68524132526190719893bcdff1a8a3cb0dd76d5d4d21cc0519c802af8d7
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
# Successfully built terminaltables
# ...

# %% [markdown]
# # Train, refer repo readme for more

# %%
# !python3 train.py --model_def config/yolov3-custom.cfg --data_config config/custom.data --pretrained_weights weights/darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 0.564173     | 0.548460     | 0.768437     |
# | x          | 0.026024     | 0.034490     | 0.065650     |
# | y          | 0.010038     | 0.022865     | 0.063073     |
# | w          | 0.028857     | 0.024023     | 0.067015     |
# | h          | 0.024566     | 0.012149     | 0.012753     |
# | conf       | 0.474604     | 0.454718     | 0.559938     |
# | cls        | 0.000085     | 0.000216     | 0.000007     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | recall50   | 0.750000     | 0.875000     | 0.875000     |
# | recall75   | 0.500000     | 0.625000     | 0.375000     |
# | precision  | 0.750000     | 0.368421     | 0.175000     |
# ...

# %% [markdown]
# # Run inference with images set aside before training

# %%
# !python3 detect.py --image_folder /content/drive/My\ Drive/license_plate_test/ --model_def config/yolov3-custom.cfg --weights_path checkpoints/yolov3_ckpt_35.pth --batch_size 2 --class_path data/custom/classes.names --checkpoint_model checkpoints/yolov3_ckpt_35.pth
# Out:
# Namespace(batch_size=2, checkpoint_model='checkpoints/yolov3_ckpt_35.pth', class_path='data/custom/classes.names', conf_thres=0.8, image_folder='/content/drive/My Drive/license_plate_test/', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='checkpoints/yolov3_ckpt_35.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.123484
# 	+ Batch 1, Inference Time: 0:00:00.125780
# 	+ Batch 2, Inference Time: 0:00:01.841786
# 	+ Batch 3, Inference Time: 0:00:01.011673
#
# Saving images:
# (0) Image: '/content/drive/My Drive/license_plate_test/Cars426.png'
# 	+ Label: licence, Conf: 1.00000
# 	+ Label: licence, Conf: 0.99932
# (1) Image: '/content/drive/My Drive/license_plate_test/Cars427.png'
# 	+ Label: licence, Conf: 0.99999
# (2) Image: '/content/drive/My Drive/license_plate_test/Cars428.png'
# 	+ Label: licence, Conf: 0.99998
# (3) Image: '/content/drive/My Drive/license_plate_test/Cars429.png'
# ...
